# %% [markdown]
# # Scrape Defensive Team Statistics from FBREF

# %%
import pandas as pd
import requests

# Base URL for fetching data
base_url = "https://fbref.com/en/comps/Big5/{season}/defense/squads/{season}-Big-5-European-Leagues-Stats"

# Seasons to fetch data for
seasons = ["2023-2024", "2022-2023", "2021-2022"]

# API Key (replace 'your_api_key' with your actual API key)
api_key = "N5R7b54EhrQT43jnYTUOsfnjX0Rd4S0HeXKqq-vIV5M"

# List to store the DataFrames
dfs = []

# Headers including the API key for authentication
headers = {"X-API-Key": "N5R7b54EhrQT43jnYTUOsfnjX0Rd4S0HeXKqq-vIV5M"}

# Iterate over the seasons to fetch data
for season in seasons:
    url = base_url.format(season=season)
    
    # Send the request and capture the response
    response = requests.get(url, headers=headers)
    
    try:
        # Ensure the request was successful
        response.raise_for_status()
        
        # Read the table from the HTML response
        tables = pd.read_html(response.text)
        
        # Assuming the first table is the one we need
        df = tables[0]

        # Clean the DataFrame by resetting the columns
        df.columns = df.columns.droplevel(0)  # Flatten MultiIndex
        df = df.rename(columns=lambda x: x if not x.startswith("Unnamed") else " ")  # Clean up column names
        df = df.reset_index(drop=True)  # Reset the index
        
        # Append the cleaned DataFrame to the list
        dfs.append(df)
        print(f"✅ Successfully fetched data for {season}")
    
    except requests.exceptions.RequestException as e:
        print(f"❌ Failed to fetch data for {season}: {e}")
    except Exception as e:
        print(f"❌ Failed to process data for {season}: {e}")

# Ensure dfs is not empty before attempting to concatenate
if dfs:
    final_df = pd.concat(dfs, ignore_index=True)
    print("✅ Successfully combined all data.")
else:
    print("⚠ No data was fetched. Exiting gracefully.")
# Out:
# /var/folders/rj/gkzv_bs14qg22pdz7mcwyfww0000gn/T/ipykernel_14392/2804924206.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
# ✅ Successfully fetched data for 2023-2024
# /var/folders/rj/gkzv_bs14qg22pdz7mcwyfww0000gn/T/ipykernel_14392/2804924206.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
# ✅ Successfully fetched data for 2022-2023
# ✅ Successfully fetched data for 2021-2022
# ✅ Successfully combined all data.
# /var/folders/rj/gkzv_bs14qg22pdz7mcwyfww0000gn/T/ipykernel_14392/2804924206.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)

# %%
dfs
# Out:
# [    Rk          Squad                Comp  # Pl   90s  Tkl  TklW  Def 3rd  \
#  0    1         Alavés          es La Liga    30  38.0  578   347      284
#  1    2        Almería          es La Liga    35  38.0  633   372      354
#  2    3        Arsenal  eng Premier League    25  38.0  610   348      257
#  3    4    Aston Villa  eng Premier League    31  38.0  547   311      269
#  4    5       Atalanta          it Serie A    29  38.0  613   369      273
#  ..  ..            ...                 ...   ...   ...  ...   ...      ...
#  91  92     Villarreal          es La Liga    32  38.0  576   348      288
#  92  93  Werder Bremen       de Bundesliga    30  34.0  604   351      303
#  93  94       West Ham  eng Premier League    26  38.0  684   426      350
#  94  95      Wolfsburg       de Bundesliga    28  34.0  550   303      272
#  95  96         Wolves  eng Premier League    27  38.0  739   430      415
#
#      Mid 3rd  Att 3rd  ...  Att  Tkl%  Lost  Blocks   Sh  Pass  Int  Tkl+Int  \
#  0       227       67  ...  629  46.1   339     363  117   246  279      857
#  1       222       57  ...  582  48.1   302     430  134   296  313      946
#  2       246      107  ...  543  49.9   272     412  106   306  292      902
#  3       210       68  ...  550  47.3   290     389  113   276  236      783
#  4       249       91  ...  597  48.7   306     483  119   364  340      953
#  ..      ...      ...  ...  ...   ...   ...     ...  ...   ...  ...      ...
#  91      212       76  ...  532  48.9   272     386  130   256  304      880
#  92      239       62  ...  609  51.2   297     434  153   281  284      888
#  93      254       80  ...  607  50.6   300     487  180   307  361     1045
#  94      201       77  ...  527  49.7   265     414   99   315  268      818
#  95      247       77  ...  607  51.4   295     506  173   333  284     1023
#
#      Clr  Err
#  0   810    5
#  1   856   19
#  2   515   18
#  3   597   13
#  4   614    7
#  ..  ...  ...
#  91  789   12
#  92  785    9
#  93  906    9
#  94  801    8
#  95  828   16
#
#  [96 rows x 21 columns],
#      Rk          Squad                Comp  # Pl   90s  Tkl  TklW  Def 3rd  \
#  0    1        Ajaccio          fr Ligue 1    36  38.0  637   382      321
#  1    2        Almería          es La Liga    29  38.0  557   322      292
#  2    3         Angers          fr Ligue 1    33  38.0  652   386      311
#  3    4        Arsenal  eng Premier League    26  38.0  568   343      238
#  4    5    Aston Villa  eng Premier League    26  38.0  632   338      305
#  ..  ..            ...                 ...   ...   ...  ...   ...      ...
#  93  94     Villarreal          es La Liga    32  38.0  578   370      276
#  94  95  Werder Bremen       de Bundesliga    25  34.0  595   349      269
#  95  96       West Ham  eng Premier League    25  38.0  608   336      290
#  96  97      Wolfsburg       de Bundesliga    28  34.0  543   324      255
#  97  98         Wolves  eng Premier League    32  38.0  660   370      363
#
#      Mid 3rd  Att 3rd  ...  Att  Tkl%  Lost  Blocks   Sh  Pass  Int  Tkl+Int  \
#  0       236       80  ...  694  45.1   381     359   85   274  420     1057
#  1       202       63  ...  623  44.9   343     435  122   313  322      879
#  2       268       73  ...  610  50.8   300     402   99   303  375     1027
#  3       212      118  ...  510  48.8   261     362   86   276  237      805
#  4       251       76  ...  648  48.1   336     438  118   320  324      956
#  ..      ...      ...  ...  ...   ...   ...     ...  ...   ...  ...      ...
#  93      201      101  ...  534  50.6   264     372  125   247  262      840
#  94      273       53  ...  617  48.6   317     371  103   268  321      916
#  95      226       92  ...  563  48.0   293     415  139   276  408     1016
#  96      206       82  ...  521  50.9   256     443  116   327  292      835
#  97      222       75  ...  616  46.3   331     497  175   322  279      939
#
#      Clr  Err
#  0   670   10
#  1   855   13
#  2   605   13
#  3   599   23
#  4   714   14
#  ..  ...  ...
#  93  691   16
#  94  789    7
#  95  810   10
#  96  701    9
#  97  817   19
#
#  [98 rows x 21 columns],
#      Rk        Squad                Comp  # Pl   90s  Tkl  TklW  Def 3rd  \
#  0    1       Alavés          es La Liga    33  38.0  550   324      271
#  1    2       Angers          fr Ligue 1    30  38.0  619   370      301
#  2    3      Arminia       de Bundesliga    26  34.0  549   311      270
#  3    4      Arsenal  eng Premier League    27  38.0  540   311      261
#  4    5  Aston Villa  eng Premier League    31  38.0  634   382      300
#  ..  ..          ...                 ...   ...   ...  ...   ...      ...
#  93  94   Villarreal          es La Liga    29  38.0  538   312      250
#  94  95      Watford  eng Premier League    30  38.0  614   356      341
#  95  96     West Ham  eng Premier League    25  38.0  534   301      273
#  96  97    Wolfsburg       de Bundesliga    30  34.0  539   298      278
#  97  98       Wolves  eng Premier League    26  38.0  673   377      377
#
#      Mid 3rd  Att 3rd  ...  Att  Tkl%  Lost  Blocks   Sh  Pass  Int  Tkl+Int  \
#  0       221       58  ...  637  41.1   375     373  106   267  376      926
#  1       253       65  ...  659  43.1   375     384   99   285  423     1042
#  2       235       44  ...  543  43.8   305     395  110   285  421      970
#  3       195       84  ...  500  48.8   256     386  123   263  296      836
#  4       259       75  ...  649  46.2   349     453  140   313  339      973
#  ..      ...      ...  ...  ...   ...   ...     ...  ...   ...  ...      ...
#  93      197       91  ...  476  48.1   247     330  109   221  329      867
#  94      213       60  ...  626  44.4   348     440  148   292  444     1058
#  95      199       62  ...  557  43.1   317     420  175   245  374      908
#  96      201       60  ...  540  47.6   283     388  103   285  388      927
#  97      242       54  ...  671  40.7   398     437  135   302  389     1062
#
#      Clr  Err
#  0   890    7
#  1   631    9
#  2   770    7
#  3   658   20
#  4   693   13
#  ..  ...  ...
#  93  644   16
#  94  899   19
#  95  781    5
#  96  740    9
#  97  820   20
#
#  [98 rows x 21 columns]]

# %% [markdown]
# # Scrape

# %%
import pandas as pd

base_url_xga = "https://fbref.com/en/comps/Big5/{season}/{season}-Big-5-European-Leagues-Stats"

xga_dfs = []

for season in seasons:
    url = base_url_xga.format(season = season)
    
    try:
        tables = pd.read_html(url)
        df = tables[0]

        df = df.rename(columns = lambda x: x if not x.startswith("Unnamed") else " ")

        df = df.reset_index(drop=True)  # Reset index
        
        xga_dfs.append(df)  # Store the cleaned DataFrame
        
        print(f"Successfully fetched data for {season}")

    except Exception as e:
        print(f"Failed to fetch data for {season}: {e}")

final_df_xga = pd.concat(xga_dfs, ignore_index=True)
# Out:
# Successfully fetched data for 2023-2024
# Successfully fetched data for 2022-2023
# Successfully fetched data for 2021-2022

# %%
# Out:
#      Rk            Squad  Country  LgRk  MP   W   D   L  GF  GA  GD  Pts  \
# 0     1       Leverkusen   de GER     1  34  28   6   0  89  24  65   90
# 1     2      Real Madrid   es ESP     1  38  29   8   1  87  26  61   95
# 2     3            Inter   it ITA     1  38  29   7   2  89  22  67   94
# 3     4  Manchester City  eng ENG     1  38  28   7   3  96  34  62   91
# 4     5          Arsenal  eng ENG     2  38  28   5   5  91  29  62   89
# ..   ..              ...      ...   ...  ..  ..  ..  ..  ..  ..  ..  ...
# 287  94            Genoa   it ITA    19  38   4  16  18  27  60 -33   28
# 288  95          Venezia   it ITA    20  38   6   9  23  34  69 -35   27
# 289  96          Watford  eng ENG    19  38   6   5  27  34  77 -43   23
# 290  97     Norwich City  eng ENG    20  38   5   7  26  23  84 -61   22
# 291  98   Greuther Fürth   de GER    18  34   3   9  22  28  82 -54   18
#
#      Pts/MP    xG   xGA   xGD  xGD/90  Attendance        Top Team Scorer  \
# 0      2.65  73.6  29.9  43.7    1.29       29994   Victor Boniface - 14
# 1      2.50  68.8  35.4  33.4    0.88       72061   Jude Bellingham - 19
# 2      2.47  78.2  31.2  47.1    1.24       72838  Lautaro Martínez - 24
# 3      2.39  80.5  35.6  44.9    1.18       53012    Erling Haaland - 27
# 4      2.34  76.1  27.9  48.2    1.27       60236       Bukayo Saka - 16
# ..      ...   ...   ...   ...     ...         ...                    ...
# 287    0.74  37.2  54.1 -16.9   -0.44       12326      Mattia Destro - 9
# 288    0.71  36.5  71.8 -35.3   -0.93        6648       Thomas Henry - 9
# 289    0.61  40.0  64.5 -24.5   -0.64       20614   Emmanuel Dennis - 10
# 290    0.58  32.3  75.5 -43.2   -1.14       26836       Teemu Pukki - 11
# 291    0.53  30.0  60.2 -30.2   -0.89        7672    Branimir Hrgota - 9
#
#            Goalkeeper
# 0      Lukáš Hrádecký
# 1        Andriy Lunin
# 2         Yann Sommer
# 3             Ederson
# 4          David Raya
# ..                ...
# 287  Salvatore Sirigu
# 288      Niki Mäenpää
# 289        Ben Foster
# 290          Tim Krul
# 291   Sascha Burchert
#
# [292 rows x 20 columns]
